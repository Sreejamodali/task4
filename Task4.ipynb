# %%
import pandas as pd
import numpy as np

# %%
data1=pd.read_csv('college_1.csv')
data2=pd.read_csv('college_2.csv')

# %%
df1=pd.DataFrame(data=data1)
df2=pd.DataFrame(data=data2)

# %%
df1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
df2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
new_df2=df2.drop(["python_en","computational_thinking"],axis=1)

# %%
#new_df2

# %%
data=pd.merge(df1,df2)
# Out:
# C:\Users\SREEJA.M\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:1204: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   warnings.warn(

# %%
data
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
ndata=df1.join(df2, how = 'left')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16500/1644327660.py in <module>
# ----> 1 ndata=df1.join(df2, how = 'left')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9097         5  K5  A5  NaN
#    9098         """
# -> 9099         return self._join_compat(
#    9100             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9101         )
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9128                     sort=sort,
#    9129                 )
# -> 9130             return merge(
#    9131                 self,
#    9132                 other,
#
# ...

# %%
df1.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0
# 3  Computer Science and Engineering       0
# 4  Computer Science and Engineering       0

# %%
df2.head()
# Out:
#                 Name  python  python_en  mysql  computational_thinking  \
# 0      ASHOK KUMAR K     100          0     31                       9
# 1            Chandru       0         20      0                       0
# 2  Ganesh Ramkumar R      -1         55     24                       6
# 3    Bodipudi Harini      -1          0     35                      -1
# 4          VIINU V P      -1        100     24                      -1
#
#    Previous Geekions  CodeKata Score  \
# 0              19400           19400
# 1              14150           14490
# 2               8790           10790
# 3              10040           10040
# 4               9150            9150
#
#                                   Department  Rising
# 0     Electronics and Electrical Engineering       0
# 1           Computer Science and Engineering     340
# 2           Computer Science and Engineering    2000
# 3  Electronics and Communication Engineering       0
# ...

# %%
data=pd.merge(df1,df2)
data.columns
# Out:
# Index(['Name', 'python', 'mysql', 'Previous Geekions', 'CodeKata Score',
#        'Department', 'Rising', 'python_en', 'computational_thinking'],
#       dtype='object')

# %%
data_merge = pd.merge(df1,                 # Full outer join
                      df2,
                      on = ["Name","python","mysql","Previous Geekions","CodeKata Score","Department","Rising"],
                      how = "outer")
print(data_merge)
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        NaN
# ...

# %%
data_merge.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN
# 3  Computer Science and Engineering       0        NaN                     NaN
# 4  Computer Science and Engineering       0        NaN                     NaN

# %%
data_merge.shape
# Out:
# (119, 9)

# %%
data_merge.to_csv("data.csv")

# %%
codekata_top=data_merge.loc[data_merge['CodeKata Score']>15000]

# %%
codekata_top.shape
# Out:
# (4, 9)

# %%
# Exceeded expectations.csv
codekata_top.to_csv(" Exceeded expectations.csv")

# %%
#Reached_expectations.csv
codekata_avg=data_merge.loc[(data_merge['CodeKata Score']<15000)&(data_merge["CodeKata Score"]>10000)]
codekata_avg.to_csv(" Reached_expectations.csv")

# %%
#Needs_Improvement.csv
codekata_notbad=data_merge.loc[(data_merge['CodeKata Score']<10000)&(data_merge["CodeKata Score"]>7000)]
codekata_notbad.to_csv("Needs_Improvement.csv")

# %%
#Unsatisfactory.csv
codekata_bad=data_merge.loc[data_merge['CodeKata Score']<7000]
codekata_bad.to_csv("Unsatisfactory.csv")

# %%
data_merge['mean_of']=data_merge[['Previous Geekions', 'CodeKata Score']].mean(axis=1)

# %%
data_merge['mean_of']
# Out:
# 0      24500.0
# 1      21740.0
# 2      19680.0
# 3      10610.0
# 4       8980.0
#         ...
# 114     2380.0
# 115     1890.0
# 116     1720.0
# 117        0.0
# 118        0.0
# Name: mean_of, Length: 119, dtype: float64

# %%
participated_students=data_merge.loc[(data_merge['Previous Geekions']>0)&(data_merge["CodeKata Score"]>0)]

# %%
participated_students.shape
# Out:
# (112, 10)

# %%
#Average completion of python course or my_sql or python english or computational thinking
data_merge[['python']].mean()
# Out:
# python    54.352941
# dtype: float64

# %%
#rising star of the week (top 3 candidate who performed well in that particular week)
data1=data_merge[['Name', 'Rising']].sort_values(['Rising'], ascending=False).head(3)

# %%
data1
# Out:
#                   Name  Rising
# 92            shifak N    3140
# 102     Narasimhan Y L    2000
# 86   Ganesh Ramkumar R    2000

# %%
#Shining stars of the week (top 3 candidates who has highest geekions)
highest_geekions=data_merge[['Name', 'Previous Geekions']].sort_values(['Previous Geekions'], ascending=False).head(3)
highest_geekions
# Out:
#           Name  Previous Geekions
# 0    A.Dharani              24500
# 1  V.JEEVITHA               21740
# 2  HEMAVATHI.R              19680

# %%
#Department wise codekata performence (pie chart)
groupof = data_merge.groupby('Department')
print(groupof['CodeKata Score'].agg(np.mean))
# Out:
# Department
# Computer Science and Engineering             5079.761905
# Electronics and Communication Engineering    2777.820513
# Electronics and Electrical Engineering       3164.705882
# Name: CodeKata Score, dtype: float64

# %%
import matplotlib.pyplot as plt
a=data_merge.Department.value_counts()['Computer Science and Engineering']
b=data_merge.Department.value_counts()['Electronics and Communication Engineering']
c=data_merge.Department.value_counts()['Electronics and Electrical Engineering']
sizes=[a,b,c]
lst=['Computer Science and Engineering','Electronics and Communication Engineering','Electronics and Electrical Engineering']
plt.figure(figsize=(2,2), dpi=200)
plt.pie(sizes, labels = lst,autopct='%1.0f%%', startangle=90)
plt.show()

# %%
#Department wise toppers (horizantal bar graph or any visual representations of your choice)
